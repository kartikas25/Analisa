# %%
import pandas as pd
import numpy as nd

# %%
data_df = pd.read_csv('C:/food_delivery_datasets.csv')
data_df.head(100)
# Out:
#       order_id  voucher_amount                   date_time  eta_seconds  \
# 0   FOOD-10455               0  2018-08-12T20:35:08.001006         1800
# 1   FOOD-10985               0  2018-09-23T17:44:12.243273         2173
# 2   FOOD-10911               0  2018-09-19T18:08:09.387991         1418
# 3   FOOD-10932               0  2018-09-21T01:24:35.272499         1903
# 4   FOOD-10961               0  2018-09-22T17:57:45.523161         1716
# ..         ...             ...                         ...          ...
# 95  FOOD-10441               0  2018-08-12T07:49:24.372746          889
# 96  FOOD-10811               0  2018-09-14T18:51:41.340585           31
# 97  FOOD-10034               0  2018-07-04T14:32:43.483011         1628
# 98  FOOD-10582               0  2018-08-25T20:49:28.694474         1244
# 99  FOOD-10259               0  2018-07-25T17:06:58.342975         2575
#
#     food_price  cust_id  rating  delivery_fee   resto_id     status  random_id
# ...

# %%
sort_harga = data_df.sort_values(by="food_price", ascending=True)
print(sort_harga)
# Out:
#         order_id  voucher_amount                   date_time  eta_seconds  \
# 202   FOOD-10654               0  2018-09-01T17:22:30.082466         1701
# 412   FOOD-10898               0  2018-09-18T13:59:20.321082         1228
# 858   FOOD-10395               0  2018-08-07T14:52:58.764328          836
# 851   FOOD-11013               0  2018-09-25T18:40:28.904590         1552
# 864   FOOD-10439               0  2018-08-11T20:16:56.407026          652
# ...          ...             ...                         ...          ...
# 1037  FOOD-10781               0  2018-09-12T17:37:10.213124         2528
# 827   FOOD-10565               0  2018-08-24T12:13:00.042608         1936
# 67    FOOD-10633               0  2018-08-31T11:47:18.090120         2474
# 10    FOOD-10386               0  2018-08-06T14:57:55.985171         2673
# 128   FOOD-10212               0  2018-07-21T18:55:34.457186         2723
#
#       food_price  cust_id  rating  delivery_fee   resto_id     status  \
# ...

# %%
print(sort_harga.iloc[0])
# Out:
# order_id                          FOOD-10654
# voucher_amount                             0
# date_time         2018-09-01T17:22:30.082466
# eta_seconds                             1701
# food_price                             12900
# cust_id                              1284060
# rating                                     5
# delivery_fee                            9000
# resto_id                           742624235
# status                             Completed
# random_id                           0.716985
# Name: 202, dtype: object
